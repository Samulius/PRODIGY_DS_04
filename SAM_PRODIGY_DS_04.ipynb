# %% [markdown]
# # TASK 4

# %% [markdown]
# # Analyze and visualize sentiment patterns in social media data to understand public opinion and attitudes towards specific topics or brands.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
print("done")
# Out:
# done

# %%
df = pd.read_csv('threads_reviews.csv')
print("done")
# Out:
# done

# %%
df.head(3)
# Out:
#         source                                 review_description  rating  \
# 0  Google Play  Meh. Not the greatest experience on a Chromebo...       2
# 1  Google Play  Pretty good for a first launch!! Its easy to u...       3
# 2  Google Play  For a brand new app, it's very well optimized....       3
#
#            review_date
# 0  2023-07-08 14:18:24
# 1  2023-07-19 20:52:48
# 2  2023-07-06 23:03:11

# %%
df.shape
# Out:
# (32910, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32910 entries, 0 to 32909
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   source              32910 non-null  object
#  1   review_description  32910 non-null  object
#  2   rating              32910 non-null  int64
#  3   review_date         32910 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 1.0+ MB

# %%
df.isnull().sum()
# Out:
# source                0
# review_description    0
# rating                0
# review_date           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(keep = "first",inplace = True)
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(6, 5))
sns.countplot(x='source', data=df, palette = ["#03C988","#1D267D"], order=df['source'].value_counts().index)
plt.title('Distribution of Sources')
plt.show()

# %%
plt.figure(figsize=(6, 5))
sns.countplot(x='rating', data=df, palette=["#7B113A", "#150E56", "#DA0037", "#52057B", "#FB2576"], order=df['rating'].value_counts().index)
plt.title('Distribution of Ratings')
plt.show()

# %%
sns.catplot(data = df, x = "source",y = "rating",kind = "point")

# %%
df['review_date'] = pd.to_datetime(df['review_date'])
plt.figure(figsize=(10,6))
sns.histplot(data=df, x='review_date',color='green', bins=50, kde=True)
plt.title('Distribution of Review Dates')
plt.xlabel('Review Date')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Word Cloud of Reviews

# %%
pip install wordcloud
print("dne")

# %%
from wordcloud import WordCloud

def create_cloud(data):
    text = df[df['rating']==data]
    text_cloud = ' '.join(txt for txt in text['review_description'])
    word_cloud = WordCloud(collocations=False,background_color='white').generate(text_cloud)
    plt.imshow(word_cloud,interpolation='bilinear')
    plt.title(f'Rating {data}')
    plt.axis('off')

create_cloud(5)

# %%
from wordcloud import WordCloud

def create_cloud(data):
    text = df[df['rating']==data]
    text_cloud = ' '.join(txt for txt in text['review_description'])
    word_cloud = WordCloud(collocations=False,background_color='white').generate(text_cloud)
    plt.imshow(word_cloud,interpolation='bilinear')
    plt.title(f'Rating {data}')
    plt.axis('off')

create_cloud(4)

# %%
from wordcloud import WordCloud

def create_cloud(data):
    text = df[df['rating']==data]
    text_cloud = ' '.join(txt for txt in text['review_description'])
    word_cloud = WordCloud(collocations=False,background_color='white').generate(text_cloud)
    plt.imshow(word_cloud,interpolation='bilinear')
    plt.title(f'Rating {data}')
    plt.axis('off')

create_cloud(3)

# %%
from wordcloud import WordCloud

def create_cloud(data):
    text = df[df['rating']==data]
    text_cloud = ' '.join(txt for txt in text['review_description'])
    word_cloud = WordCloud(collocations=False,background_color='white').generate(text_cloud)
    plt.imshow(word_cloud,interpolation='bilinear')
    plt.title(f'Rating {data}')
    plt.axis('off')

create_cloud(2)

# %%
from wordcloud import WordCloud

def create_cloud(data):
    text = df[df['rating']==data]
    text_cloud = ' '.join(txt for txt in text['review_description'])
    word_cloud = WordCloud(collocations=False,background_color='white').generate(text_cloud)
    plt.imshow(word_cloud,interpolation='bilinear')
    plt.title(f'Rating {data}')
    plt.axis('off')

create_cloud(1)

# %% [markdown]
# # Cleaning Text

# %%
# !pip install emoji
# Out:
# Collecting emoji
#   Obtaining dependency information for emoji from https://files.pythonhosted.org/packages/55/c1/1d97d960831e23a3dd8608b0b489eb4866144445475277a443efb0379609/emoji-2.11.0-py2.py3-none-any.whl.metadata
#   Downloading emoji-2.11.0-py2.py3-none-any.whl.metadata (5.3 kB)
# Downloading emoji-2.11.0-py2.py3-none-any.whl (433 kB)
#    ---------------------------------------- 0.0/433.8 kB ? eta -:--:--
#    ---------- ----------------------------- 112.6/433.8 kB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  430.1/433.8 kB 6.7 MB/s eta 0:00:01
#    ---------------------------------------  430.1/433.8 kB 6.7 MB/s eta 0:00:01
#    ---------------------------------------  430.1/433.8 kB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 433.8/433.8 kB 2.5 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.11.0

# %%
import string
import emoji
import re
def cleaning_text(text):
    text = text.lower()
    text = re.sub(r'\d+','',text)
    text = emoji.demojize(text)
    text = ''.join([i for i in text if i not in string.punctuation])
    return text
df['new_review'] = df['review_description'].apply(cleaning_text)

# %%
df.head()
# Out:
#         source                                 review_description  rating  \
# 0  Google Play  Meh. Not the greatest experience on a Chromebo...       2
# 1  Google Play  Pretty good for a first launch!! Its easy to u...       3
# 2  Google Play  For a brand new app, it's very well optimized....       3
# 3  Google Play  Great app with a lot of potential! However, th...       3
# 4  Google Play  The app is good, but it needs a lot of functio...       3
#
#           review_date                                         new_review
# 0 2023-07-08 14:18:24  meh not the greatest experience on a chromeboo...
# 1 2023-07-19 20:52:48  pretty good for a first launch its easy to use...
# 2 2023-07-06 23:03:11  for a brand new app its very well optimized ho...
# 3 2023-07-10 00:53:25  great app with a lot of potential however ther...
# 4 2023-07-06 16:57:43  the app is good but it needs a lot of function...

# %% [markdown]
# # Stemming for finding word root

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\peter\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\peter\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in c:\users\peter\anaconda3\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\peter\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\peter\anaconda3\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: colorama in c:\users\peter\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

ps = PorterStemmer()

words = word_tokenize(df['new_review'].iloc[5])
for w in words:
    print(w, ':', ps.stem(w))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Peter\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# currently : current
# its : it
# very : veri
# challenging : challeng
# to : to
# use : use
# its : it
# in : in
# dark : dark
# mode : mode
# and : and
# i : i
# want : want
# to : to
# change : chang
# it : it
# to : to
# brighten : brighten
# it : it
# up : up
# but : but
# apparently : appar
# i : i
# can : can
# only : onli
# change : chang
# it : it
# through : through
# instagram : instagram
# why : whi
# dark : dark
# mode : mode
# needs : need
# to : to
# be : be
# improved : improv
# its : it
# tough : tough
# on : on
# the : the
# eyes : eye
# and : and
# the : the
# ui : ui
# is : is
# visually : visual
# unbearable : unbear
# twitter : twitter
# nearly : nearli
# perfected : perfect
# the : the
# ui : ui
# i : i
# think : think
# its : it
# a : a
# decent : decent
# start : start
# but : but
# i : i
# cant : cant
# use : use
# it : it
# for : for
# more : more
# than : than
# a : a
# couple : coupl
# of : of
# seconds : second
# even : even
# if : if
# i : i
# wanted : want
# to : to

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Peter\AppData\Roaming\nltk_data...
# True

# %%
stemmed = []
for i in range(len(df)):
    stem_list = []
    words = word_tokenize(df['new_review'].iloc[i])
    for w in words:
        stem_list.append(ps.stem(w))
    stemmed.append(stem_list)

df['Stemmed'] = stemmed
df['Stemmed'] = df['Stemmed'].apply(' '.join)

# %%
pip install textblob
# Out:
# Collecting textblob
#   Obtaining dependency information for textblob from https://files.pythonhosted.org/packages/02/07/5fd2945356dd839974d3a25de8a142dc37293c21315729a41e775b5f3569/textblob-0.18.0.post0-py3-none-any.whl.metadata
#   Downloading textblob-0.18.0.post0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: nltk>=3.8 in c:\users\peter\anaconda3\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in c:\users\peter\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (8.0.4)
# Requirement already satisfied: joblib in c:\users\peter\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\peter\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\peter\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (4.65.0)
# Requirement already satisfied: colorama in c:\users\peter\anaconda3\lib\site-packages (from click->nltk>=3.8->textblob) (0.4.6)
# Downloading textblob-0.18.0.post0-py3-none-any.whl (626 kB)
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ------- -------------------------------- 112.6/626.3 kB 3.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 532.5/626.3 kB 6.7 MB/s eta 0:00:01
#    ---------------------------------------  624.6/626.3 kB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 626.3/626.3 kB 4.9 MB/s eta 0:00:00
# Installing collected packages: textblob
# Successfully installed textblob-0.18.0.post0
# Note: you may need to restart the kernel to use updated packages.

# %%
from textblob import TextBlob
def sentiment_analysis(ds):
    sentiment = TextBlob(ds["Stemmed"]).sentiment
    return pd.Series([sentiment.subjectivity, sentiment.polarity])

# %%
df[["subjectivity", "polarity"]] = df.apply(sentiment_analysis, axis=1)
df.head()
# Out:
#         source                                 review_description  rating  \
# 0  Google Play  Meh. Not the greatest experience on a Chromebo...       2
# 1  Google Play  Pretty good for a first launch!! Its easy to u...       3
# 2  Google Play  For a brand new app, it's very well optimized....       3
# 3  Google Play  Great app with a lot of potential! However, th...       3
# 4  Google Play  The app is good, but it needs a lot of functio...       3
#
#           review_date                                         new_review  \
# 0 2023-07-08 14:18:24  meh not the greatest experience on a chromeboo...
# 1 2023-07-19 20:52:48  pretty good for a first launch its easy to use...
# 2 2023-07-06 23:03:11  for a brand new app its very well optimized ho...
# 3 2023-07-10 00:53:25  great app with a lot of potential however ther...
# 4 2023-07-06 16:57:43  the app is good but it needs a lot of function...
#
#                                              Stemmed  subjectivity  polarity
# 0  meh not the greatest experi on a chromebook se...      0.591667  0.145000
# 1  pretti good for a first launch it easi to use ...      0.447619  0.330357
# 2  for a brand new app it veri well optim howev i...      0.574527  0.082670
# 3  great app with a lot of potenti howev there is...      0.237500  0.200000
# 4  the app is good but it need a lot of function ...      0.544167  0.250833

# %% [markdown]
# # Sentiment Analysis

# %%
def analysis(score):
    if score < 0:
        return "Negative"
    elif score == 0:
        return "Neutral"
    else:
        return "Positive"

# %%
df["sentiment_analysis"] = df["polarity"].apply(analysis)
df.head()
# Out:
#         source                                 review_description  rating  \
# 0  Google Play  Meh. Not the greatest experience on a Chromebo...       2
# 1  Google Play  Pretty good for a first launch!! Its easy to u...       3
# 2  Google Play  For a brand new app, it's very well optimized....       3
# 3  Google Play  Great app with a lot of potential! However, th...       3
# 4  Google Play  The app is good, but it needs a lot of functio...       3
#
#           review_date                                         new_review  \
# 0 2023-07-08 14:18:24  meh not the greatest experience on a chromeboo...
# 1 2023-07-19 20:52:48  pretty good for a first launch its easy to use...
# 2 2023-07-06 23:03:11  for a brand new app its very well optimized ho...
# 3 2023-07-10 00:53:25  great app with a lot of potential however ther...
# 4 2023-07-06 16:57:43  the app is good but it needs a lot of function...
#
#                                              Stemmed  subjectivity  polarity  \
# 0  meh not the greatest experi on a chromebook se...      0.591667  0.145000
# 1  pretti good for a first launch it easi to use ...      0.447619  0.330357
# 2  for a brand new app it veri well optim howev i...      0.574527  0.082670
# 3  great app with a lot of potenti howev there is...      0.237500  0.200000
# 4  the app is good but it need a lot of function ...      0.544167  0.250833
#
#   sentiment_analysis
# 0           Positive
# 1           Positive
# 2           Positive
# 3           Positive
# 4           Positive

# %%
df.sentiment_analysis.value_counts().plot(kind='bar', color=["#FFC436","#F94C10","#BB2525"])
plt.title('Sentiment Classes')
plt.show()

# %%
plt.scatter(df.polarity, df.subjectivity, color='#0D1282')
plt.title('Sentiment Analysis')
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')
# Out:
# Text(0, 0.5, 'Subjectivity')
